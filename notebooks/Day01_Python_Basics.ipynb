# %% [markdown]
# ![Python](https://img.shields.io/badge/Python-3.10-blue)
# ![Progress](https://img.shields.io/badge/Progress-Day%201-green)
# ![Goal](https://img.shields.io/badge/Goal-AI%20Engineer-red)

# %% [markdown]
# <h1 align="center">🚀 60 Days of AI</h1>
# <h3 align="center">Day 1 — Python Basics</h3>
#
# <p align="center">
# Learning Artificial Intelligence from scratch and documenting the journey.
# </p>
#
# <p align="center">
# 🔥 Python • 🤖 Machine Learning • 🧠 Deep Learning
# </p>
#
# <hr>

# %% [markdown]
# <p>
# Day 1 / 60
# </p>
#
# <progress value="1" max="60"></progress>

# %% [markdown]
# ## 📚 Topics Covered
#
# - 🖨️ Printing in Python
# - 📦 Variables
# - ➕ Basic Math Operations
# - ⌨️ User Input
# - 🧩 Mini Python Program

# %% [markdown]
# > 💡 **What I learned today**
# >
# > Python allows us to create variables, perform calculations, and interact with users using simple syntax.

# %% [markdown]
# ## 🖨️ Printing in Python
# The `print()` function displays output.

# %%
print("Hello AI World")
# Out:
# Hello AI World

# %% [markdown]
# ## 📦 Variables
#
# Variables store information in Python.

# %%
name = "xyz"
age = 100

print(name)
print(age)
# Out:
# xyz
# 100

# %% [markdown]
# ## ➕ Basic Math Operations

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Multiplication:", a * b)
# Out:
# Addition: 15
# Multiplication: 50

# %% [markdown]
# ## ⌨️ User Input
#
# The `input()` function lets the user enter information.

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: xyz
# Hello xyz

# %% [markdown]
# ## 🧩 Mini Python Program

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name)
print("Next year you will be", age + 1)
# Out:
# Enter your name: xyz
# Enter your age: 90
# Hello xyz
# Next year you will be 91

# %% [markdown]
# ## 🧠 Day 1 Reflection
#
# ✔ Learned Python basics
# ✔ Practiced variables and input
# ✔ Wrote my first mini Python program
#
# This is the **first step toward learning Artificial Intelligence.**

# %% [markdown]
# ---
#
# > “Every AI engineer started with `print("Hello World")`.”
#
# 🚀 See you on **Day 2 — Data Types**
